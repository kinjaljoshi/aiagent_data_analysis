# %% [markdown]
# <a href="https://colab.research.google.com/github/kinjaljoshi/aiagent_data_exploration/blob/main/faiss_store_metadata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install faiss-cpu sentence-transformers google-cloud-bigquery langchain_community

# %%
import nltk
nltk.download('punkt', force=True)
nltk.download('punkt_tab', force=True)
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from google.colab import auth
auth.authenticate_user()

PROJECT_ID = 'llm-text-to-sql-445914'
# !gcloud config set project $PROJECT_ID
# Out:
# Updated property [core/project].

# %% [markdown]
# ## Fetch Metadata from BigQuery

# %%
from google.cloud import bigquery
import json
from collections import defaultdict

client = bigquery.Client(project="llm-text-to-sql-445914")

# Define Project & Dataset
project_id = "llm-text-to-sql-445914"
dataset_id = "llm_text_to_sql"

# Fetch all table names in the dataset
query_tables = f"""
    SELECT table_name
    FROM `{project_id}.{dataset_id}.INFORMATION_SCHEMA.TABLES`
"""

tables_result = client.query(query_tables).result()
table_names = [row.table_name for row in tables_result]

# Initialize Dictionary for Table Definitions
table_definitions = {"tables": []}

# Iterate over tables to fetch metadata
for table_name in table_names:
    query = f"""
        SELECT
            table_name,
            column_name,
            IFNULL(description, 'No Description') AS column_description
        FROM
            `{project_id}.{dataset_id}.INFORMATION_SCHEMA.COLUMN_FIELD_PATHS`
        WHERE
            table_name = '{table_name}'
    """

    query_results = client.query(query).result()

    # Group columns into table structure
    table_dict = {
        "table_name": table_name,
        "table_description": f"Metadata for table {table_name}.",  # You can customize this if descriptions exist
        "columns": []
    }

    for row in query_results:
        table_dict["columns"].append({
            "column_name": row.column_name,
            "column_description": row.column_description
        })

    # Append formatted table data
    table_definitions["tables"].append(table_dict)

# Print the final JSON structure
print(json.dumps(table_definitions, indent=4))
# Out:
# {
#     "tables": [
#         {
#             "table_name": "XX_COMPANY_ITEMS",
#             "table_description": "Metadata for table XX_COMPANY_ITEMS.",
#             "columns": [
#                 {
#                     "column_name": "item_id",
#                     "column_description": "Unique item identifier"
#                 },
#                 {
#                     "column_name": "description",
#                     "column_description": "Item Description"
#                 },
#                 {
#                     "column_name": "uom",
#                     "column_description": "Unit Of Measure"
#                 },
#                 {
#                     "column_name": "length",
#                     "column_description": "Length dimension of item"
#                 },
#                 {
#                     "column_name": "width",
#                     "column_description": "width dimension of item"
#                 },
#                 {
#                     "column_name": "height",
#                     "column_description": "height dimension of item"
#                 },
#                 {
#                     "column_name": "weight",
#                     "column_description": "weight of item"
#                 }
#             ]
#         },
#         {
#             "table_name": "XX_COMPANY_CUSTOMERS",
#             "table_description": "Metadata for table XX_COMPANY_CUSTOMERS.",
#             "columns": [
#                 {
#                     "column_name": "customer_id",
#                     "column_description": "Unique Customer Identifier"
#                 },
#                 {
#                     "column_name": "customer_name",
#                     "column_description": "Customer Name"
#                 },
#                 {
#                     "column_name": "address",
#                     "column_description": "Customer Address"
#                 },
#                 {
#                     "column_name": "contact_name",
#                     "column_description": "Customer Contact"
#                 },
#                 {
#                     "column_name": "contact_phone",
#                     "column_description": "Contact Phone number"
#                 }
#             ]
#         },
#         {
#             "table_name": "XX_COMPANY_WAREHOUSES",
#             "table_description": "Metadata for table XX_COMPANY_WAREHOUSES.",
#             "columns": [
#                 {
#                     "column_name": "warehouse_id",
#                     "column_description": "Unique Warehouse identifier"
#                 },
#                 {
#                     "column_name": "warehouse_name",
#                     "column_description": "Warehouse Name"
#                 },
#                 {
#                     "column_name": "location",
#                     "column_description": "Warehouse Location"
#                 }
#             ]
#         },
#         {
#             "table_name": "XX_COMPANY_ORDER_HEADER",
#             "table_description": "Metadata for table XX_COMPANY_ORDER_HEADER.",
#             "columns": [
#                 {
#                     "column_name": "order_id",
#                     "column_description": "Unique order identifier"
#                 },
#                 {
#                     "column_name": "customer_id",
#                     "column_description": "Customer identifier"
#                 },
#                 {
#                     "column_name": "total_items",
#                     "column_description": "Total items in order"
#                 },
#                 {
#                     "column_name": "total_amount",
#                     "column_description": "total amount of order"
#                 },
#                 {
#                     "column_name": "order_date",
#                     "column_description": "order date"
#                 },
#                 {
#                     "column_name": "delivery_date",
#                     "column_description": "delivery date of order"
#                 },
#                 {
#                     "column_name": "status",
#                     "column_description": "status of order"
#                 }
#             ]
#         },
#         {
#             "table_name": "RX_SALES_TRANSACTIONS",
#             "table_description": "Metadata for table RX_SALES_TRANSACTIONS.",
#             "columns": [
#                 {
#                     "column_name": "TRX_ID",
#                     "column_description": "Unique Sales transaction identifier"
#                 },
#                 {
#                     "column_name": "SAL_WHS",
#                     "column_description": "Warehouse Identifier"
#                 },
#                 {
#                     "column_name": "SAL_WHN",
#                     "column_description": "Warehouse Name"
#                 },
#                 {
#                     "column_name": "SAL_WHL",
#                     "column_description": "Warehouse Region"
#                 },
#                 {
#                     "column_name": "SAL_WNC",
#                     "column_description": "Warehouse City"
#                 },
#                 {
#                     "column_name": "SAL_WHA_ONE",
#                     "column_description": "Warehouse Building Address"
#                 },
#                 {
#                     "column_name": "SAL_WHA_TWO",
#                     "column_description": "Warehouse Street Address"
#                 },
#                 {
#                     "column_name": "SAL_WHA_TRE",
#                     "column_description": "Warehouse Address City"
#                 },
#                 {
#                     "column_name": "SAL_WHA_FOR",
#                     "column_description": "Warehouse Address State"
#                 },
#                 {
#                     "column_name": "SAL_WHA_FIV",
#                     "column_description": "Warehouse Address Country"
#                 },
#                 {
#                     "column_name": "SAL_WHA_ZIP",
#                     "column_description": "Warehouse Address zip code"
#                 },
#                 {
#                     "column_name": "SAL_WHA_MGR",
#                     "column_description": "Warehouse Manager Identifier"
#                 },
#                 {
#                     "column_name": "SAL_WHA_MGAF",
#                     "column_description": "Warehouse Manager First Name"
#                 },
#                 {
#                     "column_name": "SAL_WHA_MGAL",
#                     "column_description": "Warehouse Manager Last Name"
#                 },
#                 {
#                     "column_name": "SAL_SALES_EID",
#                     "column_description": "Sales person Employee Identifier"
#                 },
#                 {
#                     "column_name": "SAL_SALES_EFN",
#                     "column_description": "Sales person First Name"
#                 },
#                 {
#                     "column_name": "SAL_SALES_ELN",
#                     "column_description": "Sales person Last Name"
#                 },
#                 {
#                     "column_name": "SAL_SALES_MID",
#                     "column_description": "Sales Manager Identifier"
#                 },
#                 {
#                     "column_name": "SAL_SALES_MIF",
#                     "column_description": "Sales Manager First Name"
#                 },
#                 {
#                     "column_name": "SAL_SALES_MIL",
#                     "column_description": "Sales Manager Last Name"
#                 },
#                 {
#                     "column_name": "SAL_SALES_CP",
#                     "column_description": "Sales person commission percentage"
#                 },
#                 {
#                     "column_name": "SAL_SALES_HD",
#                     "column_description": "Sales person hire date"
#                 },
#                 {
#                     "column_name": "SAL_SSIC",
#                     "column_description": "Sale item unique identifier"
#                 },
#                 {
#                     "column_name": "SAL_ITMN",
#                     "column_description": "Sale item number used for ordering by customer"
#                 },
#                 {
#                     "column_name": "SAL_ITMNME",
#                     "column_description": "Sale item Name"
#                 },
#                 {
#                     "column_name": "SAL_ITMDE",
#                     "column_description": "Sale item description"
#                 },
#                 {
#                     "column_name": "SAL_ITEM_UOM",
#                     "column_description": "Sale item Unit of measure"
#                 },
#                 {
#                     "column_name": "SAL_ITEM_WT",
#                     "column_description": "Sale item weight in kilogram"
#                 },
#                 {
#                     "column_name": "SAL_ITEM_L",
#                     "column_description": "Sale item Length measurement in centimeter"
#                 },
#                 {
#                     "column_name": "SAL_ITEM_W",
#                     "column_description": "Sale item Width measurement in centimeter"
#                 },
#                 {
#                     "column_name": "SAL_ITEM_H",
#                     "column_description": "Sale item Height measurement in centimeter"
#                 },
#                 {
#                     "column_name": "SAL_ITEM_DISP",
#                     "column_description": "Sale Item Disposition ('H', 'N')"
#                 },
#                 {
#                     "column_name": "SAL_ITEM_DISPD",
#                     "column_description": "Sale item disposition detail (Hazard or None)"
#                 },
#                 {
#                     "column_name": "SAL_INV_ID",
#                     "column_description": "Sale invoice unique identifier"
#                 },
#                 {
#                     "column_name": "SAL_INV_DT",
#                     "column_description": "Sale invoice creation date"
#                 },
#                 {
#                     "column_name": "SAL_INV_AMT",
#                     "column_description": "Sale invoice amount"
#                 },
#                 {
#                     "column_name": "SAL_INV_PDT",
#                     "column_description": "Sale invoice expected payment date"
#                 },
#                 {
#                     "column_name": "SAL_INVOICE_STS",
#                     "column_description": "Sale invoice status ('O', 'C')"
#                 },
#                 {
#                     "column_name": "SAL_INV_DISCA",
#                     "column_description": "Sale invoice discount amount"
#                 },
#                 {
#                     "column_name": "SAL_INV_ADJA",
#                     "column_description": "Sale invoice adjusted amount"
#                 },
#                 {
#                     "column_name": "SAL_INV_CLD",
#                     "column_description": "Sale invoice closed date"
#                 },
#                 {
#                     "column_name": "SAL_CUST_ID",
#                     "column_description": "Sale Customer Identifier"
#                 },
#                 {
#                     "column_name": "SAL_CUST_ACCT",
#                     "column_description": "Sale Customer Account Identifier"
#                 },
#                 {
#                     "column_name": "SAL_CUST_NUM",
#                     "column_description": "Sale Customer account number"
#                 },
#                 {
#                     "column_name": "SAL_CUST_A1",
#                     "column_description": "Sale Customer Billing address House number"
#                 },
#                 {
#                     "column_name": "SAL_CUST_A2",
#                     "column_description": "Sale Customer Billing address Street"
#                 },
#                 {
#                     "column_name": "SAL_CUST_A3",
#                     "column_description": "Sale Customer Billing address city"
#                 },
#                 {
#                     "column_name": "SAL_CUST_A4",
#                     "column_description": "Sale Customer Billing address state"
#                 },
#                 {
#                     "column_name": "SAL_CUST_A5",
#                     "column_description": "Sale Customer Billing address Country"
#                 },
#                 {
#                     "column_name": "SAL_CUST_A6",
#                     "column_description": "Sale Customer Billing address zip code"
#                 },
#                 {
#                     "column_name": "SAL_CUST_B1",
#                     "column_description": "Sale Customer Shipping address House number"
#                 },
#                 {
#                     "column_name": "SAL_CUST_B2",
#                     "column_description": "Sale Customer Shipping address Street"
#                 },
#                 {
#                     "column_name": "SAL_CUST_B3",
#                     "column_description": "Sale Customer Shipping address city"
#                 },
#                 {
#                     "column_name": "SAL_CUST_B4",
#                     "column_description": "Sale Customer Shipping address state"
#                 },
#                 {
#                     "column_name": "SAL_CUST_B5",
#                     "column_description": "Sale Customer Shipping address Country"
#                 },
#                 {
#                     "column_name": "SAL_CUST_B6",
#                     "column_description": "Sale Customer Shipping address zip code"
#                 },
#                 {
#                     "column_name": "SAL_QTY",
#                     "column_description": "Sale quantity"
#                 },
#                 {
#                     "column_name": "SAL_DATE",
#                     "column_description": "Date of Sale"
#                 },
#                 {
#                     "column_name": "SAL_DEL_DATE",
#                     "column_description": "Delivery date of sale"
#                 }
#             ]
#         },
#         {
#             "table_name": "XX_COMPANY_ORDER_LINES",
#             "table_description": "Metadata for table XX_COMPANY_ORDER_LINES.",
#             "columns": [
#                 {
#                     "column_name": "order_line_id",
#                     "column_description": "Unique order line identifier"
#                 },
#                 {
#                     "column_name": "order_id",
#                     "column_description": "Order identifier"
#                 },
#                 {
#                     "column_name": "item_id",
#                     "column_description": "Item identifier"
#                 },
#                 {
#                     "column_name": "quantity",
#                     "column_description": "Item quantity"
#                 },
#                 {
#                     "column_name": "unit_price",
#                     "column_description": "Unit Price of Item"
#                 },
#                 {
#                     "column_name": "total_price",
#                     "column_description": "Total price of order line"
#                 }
#             ]
#         },
#         {
#             "table_name": "XX_COMPANY_INVENTORY",
#             "table_description": "Metadata for table XX_COMPANY_INVENTORY.",
#             "columns": [
#                 {
#                     "column_name": "inventory_id",
#                     "column_description": "Unique inventory record id"
#                 },
#                 {
#                     "column_name": "warehouse_id",
#                     "column_description": "warehouse identifier"
#                 },
#                 {
#                     "column_name": "item_id",
#                     "column_description": "item identifier"
#                 },
#                 {
#                     "column_name": "stock_quantity",
#                     "column_description": "On hand stock quantity"
#                 },
#                 {
#                     "column_name": "last_updated",
#                     "column_description": "Last Updated timestamp"
#                 }
#             ]
#         }
#     ]
# }

# %% [markdown]
# ## Store Metadata in FAISS using langchain Documents

# %%
import json
from langchain_community.vectorstores import FAISS
from langchain_core.documents import Document
from langchain.embeddings.sentence_transformer import SentenceTransformerEmbeddings

# Load Sentence Transformer Model
embedding_model = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")


# Step 1: Convert Each Table into a Single LangChain Document
documents = []

for table in table_definitions["tables"]:
    # Format table description
    table_text = f"Table: {table['table_name']}\nDescription: {table['table_description']}\n\nColumns:\n"

    # Add all columns into the same document
    for column in table["columns"]:
        table_text += f"  - {column['column_name']}: {column['column_description']}\n"

    # Store full table structure in one Document
    doc = Document(
        page_content=table_text,
        metadata={"table_name": table["table_name"]}
    )
    documents.append(doc)

# Step 2: Store in FAISS Using LangChain's FAISS Wrapper
vector_db = FAISS.from_documents(documents, embedding_model)

# Save FAISS Index
vector_db.save_local("faiss_table_index")

print(f"Stored {len(documents)} table definitions in FAISS as single documents.")

# %% [markdown]
# ## Cleanup search text and get key words

# %%
# Define custom stop words (action verbs & common words)
custom_stopwords = set(stopwords.words("english")).union({"get", "put", "fetch", "retrieve", "show", "find"})

# Input Query
query_text = "Get Warehouse and item and inventory in each warehouse"

# Tokenize & Convert to Lowercase
words = word_tokenize(query_text.lower())

# Remove Stop Words & Duplicates (Preserve Order)
filtered_words = []
for word in words:
    if word not in custom_stopwords and word not in filtered_words:
        filtered_words.append(word)

# Display Extracted Key Terms
print("Key Terms:", filtered_words)
# Out:
# Key Terms: ['warehouse', 'item', 'inventory']

# %% [markdown]
# ## Retrieve Table data from FAISS using langchain vector_db similarity search

# %%
# Load FAISS Index
vector_db = FAISS.load_local("faiss_table_index", embedding_model, allow_dangerous_deserialization=True)


# Perform FAISS Search
final_docs = []
for search_text in filtered_words:
  retrieved_docs = vector_db.similarity_search(search_text, k=1)  # Retrieve top-1 match
  final_docs.append(retrieved_docs[0])
# Extract Matched Document
#matched_document = retrieved_docs[0]

# Display Full Table Definition
print("\n **Search Result:**")
for doc in final_docs:
  print(doc.page_content)
# Out:
#  **Search Result:**
# Table: XX_COMPANY_WAREHOUSES
# Description: Metadata for table XX_COMPANY_WAREHOUSES.
#
# Columns:
#   - warehouse_id: Unique Warehouse identifier
#   - warehouse_name: Warehouse Name
#   - location: Warehouse Location
#
# Table: XX_COMPANY_ITEMS
# Description: Metadata for table XX_COMPANY_ITEMS.
#
# Columns:
#   - item_id: Unique item identifier
#   - description: Item Description
#   - uom: Unit Of Measure
#   - length: Length dimension of item
#   - width: width dimension of item
#   - height: height dimension of item
#   - weight: weight of item
#
# Table: XX_COMPANY_INVENTORY
# Description: Metadata for table XX_COMPANY_INVENTORY.
#
# Columns:
#   - inventory_id: Unique inventory record id
#   - warehouse_id: warehouse identifier
#   - item_id: item identifier
#   - stock_quantity: On hand stock quantity
#   - last_updated: Last Updated timestamp
